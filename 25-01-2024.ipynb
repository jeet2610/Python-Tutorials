# %%
#7. Write a Pandas program to create a dataframe and set a title or name of the index column.
import pandas as pd
df = pd.DataFrame({
    'school_code': ['s001','s002','s003','s001','s002','s004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_Of_Birth': ['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']},
                                index = ['t1', 't2', 't3', 't4', 't5', 't6'])

print('Original DataFrame')
print(df)
df.index.name = "Index_name"
print("Said DataFrame with Index Name")
print(df)
# Out:
# Original DataFrame
#    school_code class            name date_Of_Birth  weight  address
# t1        s001     V  Alberto Franco    15/05/2002      35  street1
# t2        s002     V    Gino Mcneill    17/05/2002      32  street2
# t3        s003    VI     Ryan Parkes    16/02/1999      33  street3
# t4        s001    VI    Eesha Hinton    25/09/1998      30  street1
# t5        s002     V    Gino Mcneill    11/05/2002      31  street2
# t6        s004    VI    David Parkes    15/09/1997      32  street4
# Said DataFrame with Index Name
#            school_code class            name date_Of_Birth  weight  address
# Index_name
# t1                s001     V  Alberto Franco    15/05/2002      35  street1
# t2                s002     V    Gino Mcneill    17/05/2002      32  street2
# t3                s003    VI     Ryan Parkes    16/02/1999      33  street3
# t4                s001    VI    Eesha Hinton    25/09/1998      30  street1
# ...

# %%
#Write a Pandas program to set value in a specific cell in a given dataframe using index.

import pandas as pd
df = pd.DataFrame({
    'school_code': ['s001','s002','s003','s001','s002','s004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_Of_Birth': ['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']},
                                index = ['t1', 't2', 't3', 't4', 't5', 't6'])

print("Original DataFrame")
print(df)
df.at['t6','school_code'] = 's005'
df.at['t4','date_Of_Birth']='26/10/2001'
print("Set Value after choosing specific Index with value")
print(df)
# Out:
# Original DataFrame
#    school_code class            name date_Of_Birth  weight  address
# t1        s001     V  Alberto Franco    15/05/2002      35  street1
# t2        s002     V    Gino Mcneill    17/05/2002      32  street2
# t3        s003    VI     Ryan Parkes    16/02/1999      33  street3
# t4        s001    VI    Eesha Hinton    25/09/1998      30  street1
# t5        s002     V    Gino Mcneill    11/05/2002      31  street2
# t6        s004    VI    David Parkes    15/09/1997      32  street4
# Set Value after choosing specific Index with value
#    school_code class            name date_Of_Birth  weight  address
# t1        s001     V  Alberto Franco    15/05/2002      35  street1
# t2        s002     V    Gino Mcneill    17/05/2002      32  street2
# t3        s003    VI     Ryan Parkes    16/02/1999      33  street3
# t4        s001    VI    Eesha Hinton    26/10/2001      30  street1
# t5        s002     V    Gino Mcneill    11/05/2002      31  street2
# ...

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('dataset/RELIANCE.NS.csv',parse_dates=True,index_col=0).iloc[0:100]
print(df.info())
print("Original DataFrame")
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 100 entries, 2019-01-25 to 2019-06-26
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       100 non-null    float64
#  1   High       100 non-null    float64
#  2   Low        100 non-null    float64
#  3   Close      100 non-null    float64
#  4   Adj Close  100 non-null    float64
#  5   Volume     100 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 5.5 KB
# None
# Original DataFrame
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-01-25  1238.708252  1252.824463  1223.799561  1234.300049  1211.052246
# 2019-01-28  1238.757813  1244.156616  1210.921631  1218.004517  1195.063477
# 2019-01-29  1219.440918  1220.084839  1190.069336  1199.281982  1176.693604
# 2019-01-30  1203.591187  1213.497314  1179.915527  1184.472412  1162.162964
# ...

# %%
import mplfinance as mpf
mpf.plot(df,type='candle',volume=True,mav=(10,20),figscale=2.0)

# %%
#26. Write a Pandas program to select rows by filtering on one or more column(s) in a multi-index dataframe.

import pandas as pd
import numpy as np

df = pd.DataFrame({
    'school_code': ['s001','s002','s003','s001','s002','s004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_of_birth': ['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'weight': [35, 37, 33, 30, 31, 32],
    'tcode': ['t1', 't2', 't3', 't4', 't5', 't6']})    
print("Original DataFrame:")
print(df)
df = df.set_index(['tcode','school_code'])
print(df)
# Out:
# Original DataFrame:
#   school_code class            name date_of_birth  weight tcode
# 0        s001     V  Alberto Franco    15/05/2002      35    t1
# 1        s002     V    Gino Mcneill    17/05/2002      37    t2
# 2        s003    VI     Ryan Parkes    16/02/1999      33    t3
# 3        s001    VI    Eesha Hinton    25/09/1998      30    t4
# 4        s002     V    Gino Mcneill    11/05/2002      31    t5
# 5        s004    VI    David Parkes    15/09/1997      32    t6
#                   class            name date_of_birth  weight
# tcode school_code
# t1    s001            V  Alberto Franco    15/05/2002      35
# t2    s002            V    Gino Mcneill    17/05/2002      37
# t3    s003           VI     Ryan Parkes    16/02/1999      33
# t4    s001           VI    Eesha Hinton    25/09/1998      30
# t5    s002            V    Gino Mcneill    11/05/2002      31
# t6    s004           VI    David Parkes    15/09/1997      32

# %%
print(df.query('tcode == "t2"'))
# Out:
#                   class          name date_of_birth  weight
# tcode school_code
# t2    s002            V  Gino Mcneill    17/05/2002      37

# %%
print(df.query("school_code == 's002'"))
# Out:
#                   class          name date_of_birth  weight
# tcode school_code
# t2    s002            V  Gino Mcneill    17/05/2002      37
# t5    s002            V  Gino Mcneill    11/05/2002      31

# %%
print(df.query("school_code == 's002' "))
# Out:
#                   class          name date_of_birth  weight
# tcode school_code
# t2    s002            V  Gino Mcneill    17/05/2002      37
# t5    s002            V  Gino Mcneill    11/05/2002      31
