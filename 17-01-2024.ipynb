# %%
# Corelation in Python

import pandas as pd
full_data_for_corelation = pd.read_csv('dataset/data_duration.csv',header=0,sep=',')
cor_mat = full_data_for_corelation.corr()
print(cor_mat)
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %%
# Correlation Coefficient with Plot
import seaborn as sns
import pandas as pd
cor_mat = full_data_for_corelation.corr()
axis_corr = sns.heatmap(
    cor_mat,
    vmin=1,vmax = -1,center=None,
    cmap = sns.diverging_palette(50,500,n=500),
    square=True
)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

Drowning_Accident = [20,40,60,80,100,120,140,160,180,200]
Ice_Cream_Sale = [20,40,60,80,100,120,140,160,180,200]
Drowning = {"Drowning_Accident": [20,40,60,80,100,120,140,160,180,200],
"Ice_Cream_Sale": [20,40,60,80,100,120,140,160,180,200]}
Drowning = pd.DataFrame(data=Drowning)

Drowning.plot(x="Ice_Cream_Sale", y="Drowning_Accident", kind="scatter",marker="s")
plt.show()

correlation_beach = Drowning.corr()
print(correlation_beach)
# Out:
#                    Drowning_Accident  Ice_Cream_Sale
# Drowning_Accident                1.0             1.0
# Ice_Cream_Sale                   1.0             1.0

# %%
# Write a Pandas program to create a dataframe from a dictionary and display it.
# Sample data: {'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]}
import pandas as pd
df = pd.DataFrame({'X':[78,85,96,80,86],'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]})
print(df)
# Out:
#     X   Y   Z
# 0  78  84  86
# 1  85  94  97
# 2  96  89  96
# 3  80  83  72
# 4  86  86  83

# %%
# Pandas DataFrame: Create and display a DataFrame from a specified dictionary data which has the index labels
import pandas as pd
import numpy as np
exam_data = {'name':['Jeet','Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
             'score':[12.5,9,6.15,np.nan,9,20,14.5,np.nan,8,19],
             'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
             'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}

labels = ['a','b','c','d','e','f','g','h','i','j']
df = pd.DataFrame(exam_data,index=labels)
print(df)
# Out:
#         name  score  attempts qualify
# a       Jeet  12.50         1     yes
# b       Dima   9.00         3      no
# c  Katherine   6.15         2     yes
# d      James    NaN         3      no
# e      Emily   9.00         2      no
# f    Michael  20.00         3     yes
# g    Matthew  14.50         1     yes
# h      Laura    NaN         1      no
# i      Kevin   8.00         2      no
# j      Jonas  19.00         1     yes

# %%
# Write a Pandas program to display a summary of the basic information about a specified DataFrame and its data.
# print(df)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      10 non-null     object
#  1   score     8 non-null      float64
#  2   attempts  10 non-null     int64
#  3   qualify   10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes
# None

# %%
# 4. Write a Pandas program to get the first 3 rows of a given DataFrame.
import pandas as pd
import numpy as np

print(df)
print("First three Rows from the list")
print(df.iloc[:3])
# Out:
#         name  score  attempts qualify
# a       Jeet  12.50         1     yes
# b       Dima   9.00         3      no
# c  Katherine   6.15         2     yes
# d      James    NaN         3      no
# e      Emily   9.00         2      no
# f    Michael  20.00         3     yes
# g    Matthew  14.50         1     yes
# h      Laura    NaN         1      no
# i      Kevin   8.00         2      no
# j      Jonas  19.00         1     yes
# First three Rows from the list
#         name  score  attempts qualify
# a       Jeet  12.50         1     yes
# b       Dima   9.00         3      no
# c  Katherine   6.15         2     yes

# %%
# Write a Pandas program to select the 'name' and 'score' columns from the following DataFrame.
import pandas as pd
import numpy as np

selected_df = df[['name','score']]
print(selected_df)
# Out:
#         name  score
# a       Jeet  12.50
# b       Dima   9.00
# c  Katherine   6.15
# d      James    NaN
# e      Emily   9.00
# f    Michael  20.00
# g    Matthew  14.50
# h      Laura    NaN
# i      Kevin   8.00
# j      Jonas  19.00

# %%
# 6. Write a Pandas program to select the specified columns and rows from a given data frame.
import numpy as np
import pandas as pd
selected_df = df[['name','attempts']]
print(selected_df.iloc[:5])
# Out:
#         name  attempts
# a       Jeet         1
# b       Dima         3
# c  Katherine         2
# d      James         3
# e      Emily         2

# %%
# 7. Write a Pandas program to select the rows where the number of attempts in the examination is greater than 2.
import pandas as pd
import numpy as np
print("Number of Attempts greater than 2")
print(df[df['attempts']>2])
# Out:
# Number of Attempts greater than 2
#       name  score  attempts qualify
# b     Dima    9.0         3      no
# d    James    NaN         3      no
# f  Michael   20.0         3     yes

# %%
# Write a Pandas program to count the number of rows and columns of a DataFrame.
import pandas as pd
import numpy as np

total_rows = len(df.axes[0])
total_col = len(df.axes[1])

print("Number of Rows ",str(total_rows))
print("Number of Columns ",str(total_col))
# Out:
# Number of Rows  10
# Number of Columns  4

# %%
# 9. Write a Pandas program to select the rows where the score is missing, i.e. is NaN.

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
print("The rows where Score is Missing")
print(df[df['score'].isnull()])
# Out:
# The rows where Score is Missing
#     name  score  attempts qualify
# d  James    NaN         3      no
# h  Laura    NaN         1      no

# %%
# 10. Write a Pandas program to select the rows the score is between 15 and 20 (inclusive).
import pandas as pd
import numpy as np
print("The Rows with score between 15 and 20 ")
print(df[df['score'].between(15,20)])
# Out:
# The Rows with score between 15 and 20
#       name  score  attempts qualify
# f  Michael   20.0         3     yes
# j    Jonas   19.0         1     yes

# %%
# Write a Pandas program to select the rows where number of attempts in the examination is less than 2 and score greater than 15
import numpy as np
import pandas as pd
print("Rows where Number of Attempts in the examination is less than 2 and score greater than 15")
print(df[(df['attempts']<2) & (df['score']>15)])
# Out:
# Rows where Number of Attempts in the examination is less than 2 and score greater than 15
#     name  score  attempts qualify
# j  Jonas   19.0         1     yes

# %%
# 12. Write a Pandas program to change the score in row 'd' to 11.5.
import pandas as pd
import numpy as np

df.loc['d','score'] = 11.5
print(df)
# Out:
#         name  score  attempts qualify
# a       Jeet  12.50         1     yes
# b       Dima   9.00         3      no
# c  Katherine   6.15         2     yes
# d      James  11.50         3      no
# e      Emily   9.00         2      no
# f    Michael  20.00         3     yes
# g    Matthew  14.50         1     yes
# h      Laura    NaN         1      no
# i      Kevin   8.00         2      no
# j      Jonas  19.00         1     yes

# %%
# Write a Pandas program to calculate the sum of the examination attempts by the students.
import pandas as pd
import numpy as np
print("The sum of the Examination attempts by the Students")
print(df['attempts'].sum())
# Out:
# The sum of the Examination attempts by the Students
# 19

# %%
# 14. Write a Pandas program to calculate the mean of all students' scores. Data is stored in a dataframe.

import pandas as pd
import numpy as np
print("The Mean of all Students Scores")
print(df['score'].mean())
# Out:
# The Mean of all Students Scores
# 12.183333333333334

# %%
# Write a Pandas program to append a new row 'k' to data frame with given values for each column. Now delete the new row and return the original DataFrame.

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
print("Original Dataset")
print(df)
print("Added a new row K")
df.loc['k']=["Raj",12,1,"yes"]
print(df)
print("Deleted the newly addded row K")
df = df.drop('k')
print(df)
# Out:
# Original Dataset
#         name score attempts qualify
# a       Jeet  12.5        1     yes
# b       Dima   9.0        3      no
# c  Katherine  6.15        2     yes
# d      James  11.5        3      no
# e      Emily   9.0        2      no
# f    Michael  20.0        3     yes
# g    Matthew  14.5        1     yes
# h      Laura   NaN        1      no
# i      Kevin   8.0        2      no
# j      Jonas  19.0        1     yes
# k        Raj    12        1     yes
# Added a new row K
#         name score attempts qualify
# a       Jeet  12.5        1     yes
# b       Dima   9.0        3      no
# c  Katherine  6.15        2     yes
# d      James  11.5        3      no
# e      Emily   9.0        2      no
# f    Michael  20.0        3     yes
# g    Matthew  14.5        1     yes
# h      Laura   NaN        1      no
# i      Kevin   8.0        2      no
# j      Jonas  19.0        1     yes
# k        Raj    12        1     yes
# Deleted the newly addded row K
# ...

# %%
# Write a Pandas program to sort the DataFrame first by 'name' in descending order, then by 'score' in ascending order.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print(" The Dataframe Sorted by Name in Desc order")

df = df.sort_values(by=['name','score'],ascending=[False,True])
print(df)
# Out:
#  The Dataframe Sorted by Name in Desc order
#         name score attempts qualify
# f    Michael  20.0        3     yes
# g    Matthew  14.5        1     yes
# h      Laura   NaN        1      no
# i      Kevin   8.0        2      no
# c  Katherine  6.15        2     yes
# j      Jonas  19.0        1     yes
# a       Jeet  12.5        1     yes
# d      James  11.5        3      no
# e      Emily   9.0        2      no
# b       Dima   9.0        3      no

# %%
#  Write a Pandas program to replace the 'qualify' column contains the values 'yes' and 'no' with True and False.
import pandas as pd
import numpy as np
print("replacing the yes and no in the qualify column with true and false")
df['qualify'] = df['qualify'].map({'yes':True, 'no':False})
print(df)
# Out:
# replacing the yes and no in the qualify column with true and false
#         name score attempts  qualify
# f    Michael  20.0        3     True
# g    Matthew  14.5        1     True
# h      Laura   NaN        1    False
# i      Kevin   8.0        2    False
# c  Katherine  6.15        2     True
# j      Jonas  19.0        1     True
# a       Jeet  12.5        1     True
# d      James  11.5        3    False
# e      Emily   9.0        2    False
# b       Dima   9.0        3    False

# %%
#18 Write a Pandas program to change the name 'James' to 'Suresh' in name column of the DataFrame.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df['name'] = df['name'].replace('James','Suresh')
print("The name is Changed from James to Suresh")
print(df)
# Out:
# The name is Changed from James to Suresh
#         name score attempts  qualify
# f    Michael  20.0        3     True
# g    Matthew  14.5        1     True
# h      Laura   NaN        1    False
# i      Kevin   8.0        2    False
# c  Katherine  6.15        2     True
# j      Jonas  19.0        1     True
# a       Jeet  12.5        1     True
# d     Suresh  11.5        3    False
# e      Emily   9.0        2    False
# b       Dima   9.0        3    False

# %% [markdown]
# # 18 questions Completed
