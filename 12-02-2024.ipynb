# %%
import pandas as pd
print("Executed.........")
# Out:
# Executed.........

# %%
import time
from selenium import webdriver
from bs4 import BeautifulSoup

url = "https://www.jiomart.com/c/groceries/staples/13"

# Initialize the webdriver
driver = webdriver.Chrome()  # You need to have chromedriver installed and in your PATH

# Open the URL
driver.get(url)

# Scroll to the bottom of the page to load more items
scroll_pause_time = 7 # Adjust this value as needed
last_height = driver.execute_script("return document.body.scrollHeight")
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(scroll_pause_time)
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# Once all items are loaded, extract the HTML content
html_content = driver.page_source

# Close the webdriver
driver.quit()

# Use BeautifulSoup to parse the HTML content
soup = BeautifulSoup(html_content, 'html.parser')

# Find all items using a refined selector
results = soup.find_all('div', {'class': 'plp-card-details-container'})

# Now you can proceed with processing the results
for result in results:
    # Process each item as needed
    product_name = result.find('div', {'class': 'plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80'})
    
    product_price = result.find('div', {'class': 'jm-heading-xxs jm-mb-xxs'})
    product_discount = result.find('span', {'class': 'jm-badge'})

    print("Product Name:", product_name)
    print("Price:", product_price)
    print("Discount:", product_discount)
    print()  # Print an empty line for better readability
# Out:
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Bharat Chana Dal 1 Kg </div>
# Price: None
# Discount: None
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Just Pressed Cold Pressed Safflower Oil | 100% Pure Safflower Kusum Saffola Oil | Unrefined &amp; Zero Additives | Healthy Heart Oil | Saffola Hero Ingredient | Kachi Ghani Oil | Wood Cold Pressed Oil | Safflower Oil 5000 ML </div>
# Price: None
# Discount: <span class="jm-badge"> 34% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Super Sarvottam Physically Refined Rice Bran Oil 1 L </div>
# Price: None
# Discount: <span class="jm-badge"> 51% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Saffola Active Pro Weight Watchers Rice Bran Based Blended Oil 1 L </div>
# Price: None
# Discount: <span class="jm-badge"> 33% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Tata Iodised Salt 1 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 14% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Ganga 5 Ltr Rice bran Oil Jar </div>
# Price: None
# Discount: None
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Chakki Atta 10 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 16% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Fortune Sunlite Refined Sunflower Oil 1 L </div>
# Price: None
# Discount: <span class="jm-badge"> 18% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Refined Sunflower Oil 1 L </div>
# Price: None
# Discount: <span class="jm-badge"> 50% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Toor Dal 2 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 22% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Fortune Premium Kachi Ghani Pure Mustard Oil 1 L (Pouch) </div>
# Price: None
# Discount: <span class="jm-badge"> 23% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> 5 A Day Kashmiri Walnut Kernels (Sharabati Sweet Halves) , 750g (Pack of 3)| Kashmiri Walnuts|Akhrot </div>
# Price: None
# Discount: <span class="jm-badge"> 49% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Pure Crystal Sugar (M) 5 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 24% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Chakki Atta 5 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 22% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Almonds 500 g </div>
# Price: None
# Discount: <span class="jm-badge"> 34% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Jeera 100 g </div>
# Price: None
# Discount: <span class="jm-badge"> 58% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life (W320) Cashews 500 g </div>
# Price: None
# Discount: <span class="jm-badge"> 26% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Just Pressed Groundnut &amp; Safflower Oil Combo - Wood Cold Pressed - 1 Ltr Each </div>
# Price: None
# Discount: <span class="jm-badge"> 33% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Nutri Binge 500g California Almonds Vitals </div>
# Price: None
# Discount: <span class="jm-badge"> 53% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Gemini Refined Sunflower Oil 1 L </div>
# Price: None
# Discount: <span class="jm-badge"> 34% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Amul Pure Ghee 1 L (Pouch) </div>
# Price: None
# Discount: <span class="jm-badge"> 7% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Nandini Pure Cow Ghee 1 L (Pouch) </div>
# Price: None
# Discount: <span class="jm-badge"> 10% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Suji / Rawa 1 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 52% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> 5 A Day Kashmiri Walnut Kernels (Sharbati Sweet Halves) , 1kg (Pack of 4)| Kashmiri Walnuts| Akhrot </div>
# Price: None
# Discount: <span class="jm-badge"> 56% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Raw Peanuts 500 g </div>
# Price: None
# Discount: <span class="jm-badge"> 24% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Fortune Sunlite Refined Sunflower Oil 5 L </div>
# Price: None
# Discount: <span class="jm-badge"> 15% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Nutri Binge 500g Whole Cashews </div>
# Price: None
# Discount: <span class="jm-badge"> 55% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Suji / Rawa 500 g </div>
# Price: None
# Discount: <span class="jm-badge"> 52% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Free Flow Iodised Salt 1 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 46% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> KRISHIVAL NUTS 100% Natural Premium California Dried Almonds 250g Pack Pouch | Premium Badam Giri | High in Fiber &amp; Boost Immunity | Real Nuts | Gluten Free </div>
# Price: None
# Discount: <span class="jm-badge"> 3% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Sugar (M) 1 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 26% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Aashirvaad Superior MP Atta 10 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 16% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Sugar (M) 2 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 24% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Value Almond 500 g </div>
# Price: None
# Discount: <span class="jm-badge"> 39% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Navjeevan Jeera 500g (Cumin) </div>
# Price: None
# Discount: <span class="jm-badge"> 66% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Just Pressed Cold Pressed Safflower Oil | 100% Pure Safflower Kusum Saffola Oil | Unrefined &amp; Zero Additives | Healthy Heart Oil | Saffola Hero Ingredient | Kachi Ghani Oil | Wood Cold Pressed Oil | Safflower Oil 1000 ML </div>
# Price: None
# Discount: <span class="jm-badge"> 32% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Kachi Ghani Mustard Oil 1 L (Bottle) </div>
# Price: None
# Discount: <span class="jm-badge"> 29% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> India Gate Mogra Basmati Rice 10 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 21% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Yellow Kishmish 500 g </div>
# Price: None
# Discount: <span class="jm-badge"> 26% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> GreenFinity Mix Dry Fruits and Nuts, 1kg [Almonds, Walnuts, Cashew, Pumpkin, Cranberry, Black Raisin &amp; Many More] Healthy Gift Hamper for Every Occasion Fresh and Healthy Dry Fruits, Seeds &amp; Nuts. </div>
# Price: None
# Discount: <span class="jm-badge"> 53% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> DAIRYSAGAR GOPAL Pure Desi Cow Ghee Pure Cow Ghee for Better Digestion and Immunity 1 ltr jar-1 </div>
# Price: None
# Discount: <span class="jm-badge"> 41% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> 5 A Day Walnuts Premium Walnut InShell (Regular) 500g | Walnuts | Dry fruits | </div>
# Price: None
# Discount: <span class="jm-badge"> 37% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Gulab Gold Filtered Groundnut Oil 5 L </div>
# Price: None
# Discount: <span class="jm-badge"> 24% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Turmeric Powder 100 g </div>
# Price: None
# Discount: <span class="jm-badge"> 50% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Aashirvaad Superior MP Atta 5 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 16% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Jeera 200 g </div>
# Price: None
# Discount: <span class="jm-badge"> 59% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Patanjali Kachi Ghani Mustard Oil 1 L (Bottle) </div>
# Price: None
# Discount: None
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> 5 A Day Walnuts 2Kg Kashmiri Walnut Kernels (Sharbati Sweet Halves) , 2kg (Pack of 8) | Kashmiri Walnuts| Akhrot </div>
# Price: None
# Discount: <span class="jm-badge"> 56% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Tata Sampann White Poha 500 g </div>
# Price: None
# Discount: <span class="jm-badge"> 7% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Moong Dal 2 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 31% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Daawat Sonamasoori Rice 10 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 25% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Aashirvaad Select Sharbatti Wheat Atta 5 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 18% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Gulab Gold Filtered Groundnut Oil 1 L </div>
# Price: None
# Discount: <span class="jm-badge"> 34% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> 5 A Day Walnuts Kashmiri Light Halves Walnut Kernels 500g (Pack of 2) | Kashmiri Walnuts| Walnut| Akhrot </div>
# Price: None
# Discount: <span class="jm-badge"> 60% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Sunrich Refined Sunflower Oil 899 g </div>
# Price: None
# Discount: <span class="jm-badge"> 33% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Besan 500 g </div>
# Price: None
# Discount: <span class="jm-badge"> 54% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Coreganic 1kg 100% Natural International Premium Whole Cashews </div>
# Price: None
# Discount: <span class="jm-badge"> 61% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Maida 1 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 57% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Gowardhan Pure Cow Ghee 1 L (Pouch) </div>
# Price: None
# Discount: <span class="jm-badge"> 10% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Daawat Rozana Super Basmati Rice 1 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 23% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Safola Gold Multisource Blended Refined Edible Oil 5 L (Can) + 1 L Free (Pouch) </div>
# Price: None
# Discount: <span class="jm-badge"> 10% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Gulab Sungold Refined Sunflower Oil 15 L (Tin) </div>
# Price: None
# Discount: <span class="jm-badge"> 23% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Thick Poha / Aval 1 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 36% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Daawat Rozana Gold Basmati Rice 5 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 21% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Fortune Superfine Besan 500 g </div>
# Price: None
# Discount: <span class="jm-badge"> 31% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Patanjali Cow Ghee 500 ml (Carton) </div>
# Price: None
# Discount: <span class="jm-badge"> 5% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Daawat Rozana Super Basmati Rice 5 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 24% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Dhara Nourish Vit A E Refined Sunflower Oil 1 L </div>
# Price: None
# Discount: <span class="jm-badge"> 25% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Horaira Nutz Dry Fruits Combo Pack 1Kg Cashews 250g , Figs 250g , Raisins 250g , Almond 250g </div>
# Price: None
# Discount: <span class="jm-badge"> 62% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Gowardhan Cow Ghee 1 L (Pack of 2) Pouch With Lock &amp; Seal Container </div>
# Price: None
# Discount: <span class="jm-badge"> 15% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Tur Dal 1 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 16% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Maggi Masala Ae Magic 6 g (Pack of 12) </div>
# Price: None
# Discount: <span class="jm-badge"> 8% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life
OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Marwar Mirchi (Red Chilly powder-500g) + Haldi (Turmeric powder-200g) + Dhania (Coriander powder-200g) Agmark Spices Super Saver Combo Pack of 900g </div>
# Price: None
# Discount: <span class="jm-badge"> 40% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Farmley 8 in 1 Tasty Berry Mix Antioxidants Rich, Mix Dried Berries 400g(Pack of 2, Each 200 g) </div>
# Price: None
# Discount: <span class="jm-badge"> 50% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> BLK Foods 1Kg Indian Kishmish | Big Size Raisins ( 500g x 2) </div>
# Price: None
# Discount: <span class="jm-badge"> 75% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Tata Sampann Turmeric Powder 100 g </div>
# Price: None
# Discount: <span class="jm-badge"> 11% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Cloves 50 g </div>
# Price: None
# Discount: <span class="jm-badge"> 17% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Tata Sampann Garam Masala 100 g </div>
# Price: None
# Discount: <span class="jm-badge"> 10% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Nature's Bliss Calcutta Meetha Paan Mouth Freshner Paan mukhwas Without Supari Jar Packing FD Quality Product (400gm) </div>
# Price: None
# Discount: <span class="jm-badge"> 55% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Jeera 1 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 58% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> ERAVAT RICE I Parmal 30kg Rice | Silky Parmal I TAKA TAK RICE </div>
# Price: None
# Discount: <span class="jm-badge"> 8% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Horaira Nutz Premium Dry fruits Combo Pack 750gm Cashew , Almond , Raisins (Pack of 3 Each 250gm) </div>
# Price: None
# Discount: <span class="jm-badge"> 53% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Dynamix Cow Ghee 1 L (Pouch) </div>
# Price: None
# Discount: <span class="jm-badge"> 15% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Tata Sampann Unpolished Urad Dal 1 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 10% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Whole Urad 500 g </div>
# Price: None
# Discount: <span class="jm-badge"> 19% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Fortune Soya Wadi / Chunks 1 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 34% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Popcorn Maize 500 g </div>
# Price: None
# Discount: <span class="jm-badge"> 20% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Red Rajma 500 g </div>
# Price: None
# Discount: <span class="jm-badge"> 16% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> VEER BRAND ROYAL - Extra Long Grain XXXL 5 Kg Biryani Basmati Rice </div>
# Price: None
# Discount: <span class="jm-badge"> 40% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life California Roasted &amp; Salted Pista 500 g </div>
# Price: None
# Discount: None
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Dry Mart Kashmiri Walnuts 1KG Without Shell/Premium Fresh Walnut Kernels/Akhrot Giri, Healthy &amp; Delightful, Used for Snacking, Ingredient for Recipes, Cuisines &amp; Desserts, Vaccum Pack (250GM*4) </div>
# Price: None
# Discount: <span class="jm-badge"> 45% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Catch Kashmiri Mirch Powder 100 g </div>
# Price: None
# Discount: <span class="jm-badge"> 33% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Fenugreek 100 g </div>
# Price: None
# Discount: <span class="jm-badge"> 24% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Flax Seeds 100 g </div>
# Price: None
# Discount: <span class="jm-badge"> 8% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Vandevi Bandhani No 1 Hing Powder 100 g </div>
# Price: None
# Discount: <span class="jm-badge"> 50% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> DAIRYSAGAR DAIRY MAKHAN Pure Desi COW Ghee ||Pure Ghee for Better Digestion and Immunity-1 ltr TetraPack </div>
# Price: None
# Discount: <span class="jm-badge"> 41% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Poppy Seed 100 g </div>
# Price: None
# Discount: <span class="jm-badge"> 22% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Nuttz Bites Premium Roasted &amp; Salted Pistachios Nut 250g (Pack of 2) </div>
# Price: None
# Discount: <span class="jm-badge"> 45% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Saffola Active Pro Weight Watchers Blended Oil 15 L </div>
# Price: None
# Discount: <span class="jm-badge"> 30% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Big Crystal Diamond Sugar 200 g </div>
# Price: None
# Discount: <span class="jm-badge"> 9% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> The Oil Factory 5.25L Extra Light Olive Oil | Ideal for All Indian Cooking | Imported from Spain </div>
# Price: None
# Discount: <span class="jm-badge"> 65% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Catch Turmeric Powder 200 g </div>
# Price: None
# Discount: <span class="jm-badge"> 33% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Future life Oats Atta | Whole Grains Oats | With Targeted Minerals of Zinc, Chromium, and Magnesium | Gluten-free | High Fiber and Protein | 100% Healthy &amp; Natural | 1kg Pouch </div>
# Price: None
# Discount: <span class="jm-badge"> 15% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Good Life Tibar Basmati Rice 1 kg </div>
# Price: None
# Discount: <span class="jm-badge"> 20% OFF </span>

# %%
len(results)
# Out:
# 322

# %%
# Puting Everything in loop

product_name = []
product_price = []
product_discount = []
for i in range(len(results)):
    badge_element = results[i].find('span', {'class': 'jm-badge'})
    product_name.append(results[i].find('div',{'class':'plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80'}).get_text().strip())
    product_price.append(results[i].find('span',{'class':'jm-heading-xxs jm-mb-xxs'}).get_text().strip())
    if badge_element is not None:
        text_inside_badge = badge_element.get_text().strip()
        if text_inside_badge:  # Check if the text is not an empty string
            product_discount.append(text_inside_badge)
        else:
            # Handle the case when the text is empty, e.g., set a default value
            product_discount.append("None")  # Replace "No Discount" with your desired default value
    else:
        # Handle the case when the element is not found, e.g., set a default value
        product_discount.append("None")
print("Executed.....................")
# Out:
# Executed.....................

# %%
data = {'Product Name':product_name,'Price':product_price,'Discount':product_discount}
df = pd.DataFrame(data)
print("executed......")
# Out:
# executed......

# %%
df['Discount'] = df['Discount'].replace('None','0% OFF')
print("executed....")
# Out:
# executed....

# %%
# Price C
df['Price'] = df['Price'].str[1:]
print("executed....")
# Out:
# executed....

# %%
df['Price'] = df['Price'].str.replace(',', '').astype(float)
print("executed....")
# Out:
# executed....

# %%
# discount data from 0% off to 0
df['Discount'] = df['Discount'].str[0:-5]
print("executed....")
# Out:
# executed....

# %%
df
# Out:
#                                           Product Name   Price Discount
# 0                                Bharat Chana Dal 1 Kg    60.0        0
# 1    Just Pressed Cold Pressed Safflower Oil | 100%...  1699.0       34
# 2    Super Sarvottam Physically Refined Rice Bran O...    97.0       51
# 3    Saffola Active Pro Weight Watchers Rice Bran B...   106.0       33
# 4                               Tata Iodised Salt 1 kg    24.0       14
# ..                                                 ...     ...      ...
# 317          Good Life Big Crystal Diamond Sugar 200 g    20.0        9
# 318  The Oil Factory 5.25L Extra Light Olive Oil | ...  1700.0       65
# 319                        Catch Turmeric Powder 200 g    48.0       33
# 320  Future life Oats Atta | Whole Grains Oats | Wi...   185.0       15
# 321                  Good Life Tibar Basmati Rice 1 kg    79.0       20
#
# [322 rows x 3 columns]

# %%
# converting discount column to FLOAT
df['Discount'] = df['Discount'].astype(float)
print("executed......")
# Out:
# executed......

# %%
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')
df['Discount'] = pd.to_numeric(df['Discount'], errors='coerce')
print("executed..........")
# Out:
# executed..........

# %%
df['Original Price'] = df['Price']/ (1-df['Discount']/100)
print('executed..........')
# Out:
# executed..........

# %%
df['Original Price'] = round(df['Original Price'])
print('executed ...... ...... ..')
# Out:
# executed ...... ...... ..

# %%
df['Original Price'].max()
# Out:
# 4857.0

# %%
df.to_csv('jiomart/Jiomart_staples(16-02-2024).csv',index=False)

# %% [markdown]
# ### Snacks
