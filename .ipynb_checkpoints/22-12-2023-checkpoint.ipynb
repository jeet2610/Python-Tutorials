# %% [markdown]
# # Scipy Interpolation

# %%
# 1D interpolation is used to interpolate a distribution with 1 variable

from scipy.interpolate import interp1d
import numpy as np

# %%
xs = np.arange(10)
ys = 2*xs + 1
interp_func = interp1d(xs,ys)
newarr = interp_func(np.arange(2.1,3,0.1))
print(newarr)
# Out:
# [5.2 5.4 5.6 5.8 6.  6.2 6.4 6.6 6.8]

# %%
# Spline Interpolation
from scipy.interpolate import UnivariateSpline
import numpy as np

xs = np.arange(10)
ys = xs**2 + np.sin(xs) + 1

interp_func = UnivariateSpline(xs, ys)

newarr = interp_func(np.arange(2.1, 3, 0.1))

print(newarr)
# Out:
# [5.62826474 6.03987348 6.47131994 6.92265019 7.3939103  7.88514634
#  8.39640439 8.92773053 9.47917082]

# %%
# Interpolation with Radial Basis Function
from scipy.interpolate import Rbf
import numpy as np

xs = np.arange(10)
ys = xs**2 + np.sin(xs) + 1

interp_func = Rbf(xs, ys)

newarr = interp_func(np.arange(2.1, 3, 0.1))

print(newarr)
# Out:
# [6.25748981 6.62190817 7.00310702 7.40121814 7.8161443  8.24773402
#  8.69590519 9.16070828 9.64233874]

# %% [markdown]
# # Significance Test in Scipy

# %% [markdown]
# ### T-Test

# %%
import numpy as np
from scipy.stats import ttest_ind

v1 = np.random.normal(size=100)
v2 = np.random.normal(size=100)

res = ttest_ind(v1,v2)
print(res)
# Out:
# TtestResult(statistic=-1.2901909167931018, pvalue=0.1984891075030536, df=198.0)

# %%
res = ttest_ind(v1,v2).pvalue
print(res)
# Out:
# 0.1984891075030536

# %%
res =ttest_ind(v1,v2).statistic
print(res)
# Out:
# -1.2901909167931018

# %% [markdown]
# ### KS-Test

# %%
# ks is used to check if the given values follow distribution

import numpy as np
from scipy.stats import kstest

v = np.random.normal(size=100)
res = kstest(v,'norm')
print(res)
# Out:
# KstestResult(statistic=0.11769205863511967, pvalue=0.1155086297731297, statistic_location=-0.019282326485849398, statistic_sign=1)

# %% [markdown]
# # Statistical Description of Data
# It returns the following description:
#
# number of observations (nobs)
# <br> minimum and maximum values = minmax
# <br>mean
# <br>variance
# <br>skewness
# <br>kurtosis

# %%
# Show statistical description of the values in an array:

import numpy as np
from scipy.stats import describe

v = np.random.normal(size=100)
res = describe(v)

print(res)
# Out:
# DescribeResult(nobs=100, minmax=(-1.8620773995640534, 3.2324030274797404), mean=0.08615116245401314, variance=0.8571728681117642, skewness=0.2423625500928518, kurtosis=0.3301795432088652)

# %% [markdown]
# ### Normality tests are based on the skewness and kurtosis

# %%
import numpy as np
from scipy.stats import skew, kurtosis

v = np.random.normal(size=100)

print(skew(v))
print(kurtosis(v))
# Out:
# 0.11923508856809087
# -0.42150092612041234

# %%
# Find if the data comes from a normal distribution:

import numpy as np
from scipy.stats import normaltest

v = np.random.normal(size=100)

print(normaltest(v))
# Out:
# NormaltestResult(statistic=0.37575486375485767, pvalue=0.8287162752060518)

# %% [markdown]
# # Matplotlib

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
xpoints = np.array([0,6])
ypoints = np.array([0,250])
plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
x = np.array([0,100])
y = np.array([0,80])
plt.plot(x,y)
plt.show()

# %%
import numpy as np
x = np.array([0,100])
y = np.array([0,80])
plt.plot(x,y,"o")
plt.show()

# %%
import numpy as np
x = np.array([0,100])
y = np.array([0,80])
plt.plot(x,y,"o",ms=20)
plt.show()

# %%
import numpy as np
x = np.array([0,100])
y = np.array([0,80])
plt.plot(x,y,marker="X",ms=20)
plt.show()

# %%
import numpy as np
x = np.array([0,100])
y = np.array([0,80])
plt.plot(x,y,"X:C1",ms=20)
plt.show()

# %%
import numpy as np
x = np.array([0,100,120,10])
y = np.array([0,80,30,3])
plt.scatter(x,y,marker="X")
plt.show()

# %%
import numpy as np

x = np.array([0,100,120,0])
y = np.array([0,80,30,0])
plt.grid()
plt.plot(x,y,marker="X",ms=10)
plt.show()

# %%
#linspace in pyplot

import matplotlib.pyplot as plt
import numpy as np

p = np.pi
print("p:",p)
x = np.linspace(-p,p)
print("x:",x)
y=np.sin(x)
plt.grid()
plt.plot(x,y,'b')
y = np.cos(x)
plt.plot(x,y,'yellow')
plt.show()
# Out:
# p: 3.141592653589793
# x: [-3.14159265 -3.01336438 -2.88513611 -2.75690784 -2.62867957 -2.5004513
#  -2.37222302 -2.24399475 -2.11576648 -1.98753821 -1.85930994 -1.73108167
#  -1.60285339 -1.47462512 -1.34639685 -1.21816858 -1.08994031 -0.96171204
#  -0.83348377 -0.70525549 -0.57702722 -0.44879895 -0.32057068 -0.19234241
#  -0.06411414  0.06411414  0.19234241  0.32057068  0.44879895  0.57702722
#   0.70525549  0.83348377  0.96171204  1.08994031  1.21816858  1.34639685
#   1.47462512  1.60285339  1.73108167  1.85930994  1.98753821  2.11576648
#   2.24399475  2.37222302  2.5004513   2.62867957  2.75690784  2.88513611
#   3.01336438  3.14159265]

# %%
#pie chart

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fruits = ["Apple","Banana","Orange","Mango"]
y = np.array([30,15,10,55])
myexplode = [0.1,0.2,0.3,0]

plt.pie(y,labels=fruits,explode=myexplode)
plt.show()

# %%
#draw graph from points (0,10)(-2,0)(2,21)
#equation 0.125x2 + 5.25x + 10

import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-2,2,100)
a = np.array([0,-2,2])
b = np.array([10,0,21])
plt.grid()
plt.plot(x,0.125*x**2+5.25*x+10)
plt.scatter(a,b)
plt.show()

# %%
#task 2
# Write a Python program to draw a line using given axis values with suitable label in the x axis , y axis and a title

import numpy as np
import matplotlib.pyplot as plt
# 2,1)4,2)1,3

a = np.array([2,4,1])
b = np.array([1,2,3])
plt.grid()
plt.plot(b,a)

# %% [markdown]
# Write a Python program to draw a line using given axis values taken from a text file, with suitable label in the x axis, y axis and a title.
# <br>Test Data:
# <br>test.txt
# <br>1 2
# <br>2 4
# <br>3 1

# %%
import matplotlib.pyplot as plt
with open("text.txt") as f:
    data = f.read()
data = data.split('\n')
x = [row.split(' ')[0] for row in data]
y = [row.split(' ')[1] for row in data]
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Sample Graph')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[119], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 with open("test.txt") as f:
#       3     data = f.read()
#       4 data = data.split('\n')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'
