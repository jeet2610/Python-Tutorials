# %%
import time
from selenium import webdriver
from bs4 import BeautifulSoup

url = "https://www.jiomart.com/c/groceries/beverages/33"

# Initialize the webdriver
driver = webdriver.Chrome()  # You need to have chromedriver installed and in your PATH

# Open the URL
driver.get(url)

# Scroll to the bottom of the page to load more items
scroll_pause_time = 3 # Adjust this value as needed
last_height = driver.execute_script("return document.body.scrollHeight")
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(scroll_pause_time)
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# Once all items are loaded, extract the HTML content
html_content = driver.page_source

# Close the webdriver
driver.quit()

# Use BeautifulSoup to parse the HTML content
soup = BeautifulSoup(html_content, 'html.parser')

# Find all items using a refined selector
results = soup.find_all('div', {'class': 'plp-card-details-container'})

# Now you can proceed with processing the results
for result in results:
    # Process each item as needed
    product_name = result.find('div', {'class': 'plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80'})
    product_price = result.find('div', {'class': 'jm-heading-xxs jm-mb-xxs'})
    product_discount = result.find('span', {'class': 'jm-badge'})

    print("Product Name:", product_name)
    print("Price:", product_price)
    print("Discount:", product_discount)
    print()  # Print an empty line for better readability
# Out:
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Frooti Mango Drink 125 ml </div>
# Price: None
# Discount: None
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Rk Home Made Natural Syrup Lemon Pudina Syrup, 750 Ml </div>
# Price: None
# Discount: <span class="jm-badge"> 61% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Appy Fizz 250 ml </div>
# Price: None
# Discount: <span class="jm-badge"> 10% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Bevzilla 60 Instant Coffee Powder Sachets(4 Flavours) - 120 Grams | Turkish Hazelnut, Colombian Gold, French Vanilla &amp; English Butterscotch | 15 Sachets Each Flavour| Makes 60 Cups| 100 % Arabica Coffee| Strong Coffee </div>
# Price: None
# Discount: <span class="jm-badge"> 48% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> B Natural Chatpata Jamun Juice 1 L </div>
# Price: None
# Discount: <span class="jm-badge"> 50% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Biovitalia Organics Plant-Based Vitamin B12 Capsules - Support Nerve Function &amp; Energy Metabolism - 60 Veg Caps, ISO Certified| WHO GMP Animal Cruelty-Free| 100% Vegan Gelatin Free| USDA I HACCP </div>
# Price: None
# Discount: <span class="jm-badge"> 33% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Nescafe Classic Instant Coffee Powder 190 g </div>
# Price: None
# Discount: <span class="jm-badge"> 10% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Tetley Lemon &amp; Honey Green Tea Bags 100 pcs </div>
# Price: None
# Discount: <span class="jm-badge"> 50% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Cadbury Hot Chocolate Powder 200 g </div>
# Price: None
# Discount: <span class="jm-badge"> 23% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Aarambh Kadak Tea 500 g </div>
# Price: None
# Discount: <span class="jm-badge"> 19% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Tang Orange Instant Drink Mix 500 g </div>
# Price: None
# Discount: <span class="jm-badge"> 19% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Biovitalia Organics Premium Multivitamin for Women Capsules - Comprehensive Nutritional Support with Shatavari, Ashwagandha, Wheatgrass &amp; More - 60 Vegan Capsules </div>
# Price: None
# Discount: <span class="jm-badge"> 40% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Cambridge Tea Party Kashmiri Kahwa 30 Tea Bags, Saffron Almond Cardamom Clove Pepper Cinnamon Rose Tulsi Green Tea </div>
# Price: None
# Discount: <span class="jm-badge"> 33% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Continental Speciale Instant Coffee Powder 50g Pouch | BUY 1 + GET 1 FREE | PACK OF 2 | 100% Pure Coffee | 100g (50g * 2 Pouches) </div>
# Price: None
# Discount: <span class="jm-badge"> 50% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Horlicks Women's Plus Caramel 750 g </div>
# Price: None
# Discount: <span class="jm-badge"> 27% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Rk Home Made Natural Syrup Rose Falooda Syrup, 750 Ml </div>
# Price: None
# Discount: <span class="jm-badge"> 61% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Biovitalia Organics Premium Milk Thistle Capsules for Liver Health &amp; Antioxidant Support - Silybum Marianum Extract - 60 Vegan Capsules - Dietary Supplement </div>
# Price: None
# Discount: <span class="jm-badge"> 16% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Biovitalia Organics Premium Saw Palmetto Capsules for Prostate Health &amp; Urinary Tract Support - Natural Serenoa Repens Extract - 60 Vegan Capsules - Dietary Supplement </div>
# Price: None
# Discount: <span class="jm-badge"> 54% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Tulsi Tea Brokens - Kadak Dana Chai 1kg | G.M.’S TULSI TEA </div>
# Price: None
# Discount: <span class="jm-badge"> 5% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Biovitalia Organics Ashwagandha Capsules - Stress Management, Mood Enhancement, Sleep Support - 60 Veg Caps, ISO Certified| WHO GMP Animal Cruelty-Free| 100% Vegan Gelatin Free| USDA I HACCP </div>
# Price: None
# Discount: <span class="jm-badge"> 37% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Biovitalia Organics Watermelon Flavored Nutraceutical Apple Cider Vinegar Effervescent Tablets - Boost Metabolism, Manage Weight &amp; Support Digestion - 15 Tablets </div>
# Price: None
# Discount: <span class="jm-badge"> 25% OFF </span>
#
# Product Name: <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Tulsi Tea Brokens | CTC - Dana Chai Patti | Combo Pack 1kg + 1kg | Kadak Chai Patti | Gujarat ki Chai | Strong and Aromatic Blend For Gujarati Chai Lovers | Assam Chai Patti | G.M.’S TULSI TEA </div>
# Price: None
# Discount: <span class="jm-badge"> 10% OFF </span>

# %%
len(results)
# Out:
# 22

# %%
results[0].find('div',{'class':'plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80'}).get_text().strip()
# Out:
# 'Mirinda Orange 250 ml'

# %%
# price
results[0].find('span',{'class':'jm-heading-xxs jm-mb-xxs'}).get_text().strip()
# Out:
# '₹18.00'

# %%
#discount
results[0].find('span',{'class':'jm-badge'}).get_text().strip()
# Out:
# '10% OFF'

# %%
# Puting Everything in loop

product_name = []
product_price = []
product_discount = []
for i in range(len(results)):
    badge_element = results[i].find('span', {'class': 'jm-badge'})
    product_name.append(results[i].find('div',{'class':'plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80'}).get_text().strip())
    product_price.append(results[i].find('span',{'class':'jm-heading-xxs jm-mb-xxs'}).get_text().strip())
    if badge_element is not None:
        text_inside_badge = badge_element.get_text().strip()
        if text_inside_badge:  # Check if the text is not an empty string
            product_discount.append(text_inside_badge)
        else:
            # Handle the case when the text is empty, e.g., set a default value
            product_discount.append("None")  # Replace "No Discount" with your desired default value
    else:
        # Handle the case when the element is not found, e.g., set a default value
        product_discount.append("None")

# %%
product_name
# Out:
# ['Maaza Mango Drink 1.2 L',
#  'Biovitalia Organics Watermelon Flavored Nutraceutical Apple Cider Vinegar Effervescent Tablets - Boost Metabolism, Manage Weight & Support Digestion - 15 Tablets',
#  'Brooke Bond Red Label Strong Blend Tea 1 kg',
#  'Maaza Mango Drink 600 ml',
#  'Thums Up 2.25 L',
#  'Rk Home Made Natural Syrup Lemon Pudina Syrup, 750 Ml',
#  'Bisleri Soda 750 ml',
#  'Taj Mahal Tea 1 kg',
#  'Red Bull Energy Drink 250 ml (4 pcs)',
#  'Kinley Soda 750 ml',
#  'Mirinda Orange 2.25 L',
#  'Tulsi Tea Brokens - Kadak Dana Chai 1kg | G.M.’S TULSI TEA',
#  'Nikunj Real Elaichi Tea, 1kg',
#  'Monster Energy Drink 350 ml',
#  '7Up 2.25 L',
#  'Tata Tea Premium Desh Ki Chai 1 kg',
#  'Pepsi 750 ml',
#  'Biovitalia Organics Premium Saw Palmetto Capsules for Prostate Health & Urinary Tract Support - Natural Serenoa Repens Extract - 60 Vegan Capsules - Dietary Supplement',
#  'Mirinda Orange 750 ml',
#  'Tata Agni Strong Leaf Tea 1 kg',
#  'Tata Gold Leaf Tea 500 g',
#  'Thums Up 600 ml',
#  'Bournvita 1 kg',
#  'Rk Home Made Natural Syrup Pan Pasand Syrup Concentrated Syrups And Squash, 750 Ml',
#  'Tata Agni Tea 250 g',
#  'Sprite 600 ml',
#  'Pepsi 2.25 L',
#  'Horlicks Classic Malt 750 g',
#  'Brooke Bond Taaza Leaf Tea 1 kg',
#  'Rk Home Made Natural Syrup Rose Falooda Syrup, 750 Ml',
#  'Nikunj Assam Tea, 1kg',
#  'Diet Coke 300 ml',
#  'Tropicano Slice Mango Drink 1.75 L',
#  'Dabur Chyawanprash 3x Immunity With Awaleha 950 g',
#  'Tata Gold Leaf Tea 1 kg',
#  'Biovitalia Organics Premium Milk Thistle Capsules for Liver Health & Antioxidant Support - Silybum Marianum Extract - 60 Vegan Capsules - Dietary Supplement',
#  'Society Tea 1 kg',
#  'Coca Cola Zero Sugar 300 ml',
#  'Brooke Bond Red Label Natural Care Tea 250 g',
#  'Maaza Refresh Mango Drink 135 ml (10 pcs)',
#  'Wagh Bakri Premium Leaf Tea 250 g',
#  'Tulsi Tea Classic | CTC Chai Patti | Family Combo Pack (2KG + 500GM Free) | Strong and Rich Blend For Tea Lovers | G.M.’S TULSI TEA',
#  'Mountain Dew 750 ml',
#  'B Natural Mixed Fruit Juice 1 L',
#  'Pepsi 250 ml',
#  'Wagh Bakri Premium Leaf Tea 500 g',
#  'MAHARASTRA CHAHA WITH "CUP" - Special Chai (Pack 2) 1 Kg Each Jar 500gm',
#  'Rk Home Made Natural Syrup Real Fruit Pineapple Crush Concentrated Syrups And Squash, 750 Ml',
#  'Frooti Mango Drink 2 L',
#  'Bournvita 750 g',
#  'Coca Cola 2.25 L',
#  'Horlicks Chocolate Delight 750 g',
#  'Storia Tender Coconut Water 1 L',
#  'Rk Home Made Natural Syrup Orange Concentrated Syrups And Squash, 750 Ml',
#  'Real Fruit Power Apple Juice 1 L',
#  'Nikunj Dhaba Special Leaf Tea, 1 kg',
#  'Frooti Mango Drink 1.2 L',
#  'Bournvita 75 g',
#  'Nikunj Dhaba Special Leaf Tea, 1.5 kg Budget Pack',
#  'Red Label Leaf Tea 250 g (Carton)',
#  'Sprite 250 ml',
#  'Fanta Orange 2.25 L',
#  'Tata Agni Leaf Tea 1.5 kg',
#  'Nescafe Classic Instant Coffee 90 g',
#  'Coca Cola 600 ml',
#  'Thums Up 250 ml',
#  'Amul Pro Whey Protein Drink 500 g',
#  'Fanta Orange 300 ml',
#  'Nescafe Classic Instant Coffee 45 g',
#  'Brooke Bond Red Label Natural Care Tea 500 g',
#  'Continental XTRA Coffee Powder 200gm Pouch | Strongest Instant Coffee | PACK OF 1 |',
#  'Society Elaichi Adrak Chai | Society Tea | Ginger & Cardamom | Refreshing & Tasteful | 250 g | Pack of 1',
#  'B Natural Guava Juice 1 L',
#  'Sprite 300 ml',
#  'Mountain Dew 250 ml',
#  'Tea Valley Utsah Dumdar Chai 900Gm | KADAK, MALTY, Aromatic & Strong | Unique Blend of Assam and Dooars CTC |',
#  'Paper Boat Coconut Water 200 ml',
#  "Women's Horlicks Plus Caramel Drink Mix 400 g",
#  'Lipton Honey Lemon Green Tea Bags 1.4 g (25 pcs)',
#  'Taj Mahal Tea 100 g (Carton)',
#  'Society Tea 250 g',
#  'BRU Instant Coffee 50 g',
#  'Tata Gold Tea 250 g',
#  'Horlicks Classic Malt 1 kg',
#  'ColombianBrewCoffee Arabica Espresso Filter Coffee Powder, Roast & Ground Strong, 100g',
#  'Rage Coffee 50 Gms Irish Hazelnut Flavour',
#  'Limca 250 ml',
#  'B Natural Orange Juice 1 L',
#  'Real Fruit Power Masala Pomegranate Juice 1 L',
#  'Society Tea 500 g',
#  'Continental XTRA Coffee Powder 50g Pouch | BUY 1 + GET 1 FREE | Strongest Instant Coffee | PACK OF 2 | 100g (50g * 2 Pouches)',
#  'Continental STRONG Coffee Powder 1 Kg Bag ( 5 Pouches of 200g )',
#  'Real Fruit Power Masala Mixed Fruit Drink 1 L',
#  'B Natural Litchi Juice 1 L',
#  'Taj Mahal Tea 250 g (Carton)',
#  'Pediasure 7 Plus Chocolate Drink Powder 400 g',
#  'Nescafe Classic Instant Coffee 24 g',
#  'Real Fruit Power Mixed Fruit Juice 1 L',
#  'Octavius | KADAK Assam Tea - 2.5 Kg | Extra Strong Assam Tea | Black Tea | Kadak Chai Patti | Loose Tea | Strong Chai | Tea Powder | Chai Patti | Taza Tea | Garden Fresh Tea | Tea 2.5 Kg',
#  '7Up 250 ml (Can)',
#  'Limca 600 ml',
#  'Bisleri Limonata 600 ml',
#  'MAHARASTRA CHAHA WITH "CUP" - Leaf Tea -1 kg (500 gm Jar Pack of 2)',
#  'Aarambh Kadak Tea 1 kg',
#  'Storia Pomegranate 100% Juice with No Added Sugar & Preservatives 750 ml',
#  'Zandu Sona Chandi Chyawanplus 900 g',
#  'B Natural Apple Juice 1 L',
#  'Horlicks Chocolate Delight 1 kg',
#  'Surewater with Minerals Package Drinking Water 1 L',
#  'Horlicks Lite Regular Malt 450 g',
#  'Lipton Pure & Light Green Tea 100 g',
#  'Bisleri Packaged Drinking Water 250 ml',
#  'Tata Tea Premium Tea 1.5 kg',
#  'Frooti 600 ml',
#  'Manama Lime and Mint Mojito Syrup for Mocktails & Cocktails (750ML)',
#  'BRU Green Label Filter Coffee Powder 500 g',
#  'Mirinda Orange 250 ml',
#  'Complan Royale Chocolate Drink Powder 1 kg',
#  'Mirinda Orange 250 ml',
#  'B Natural Mixed Fruit Juice 180 ml',
#  'Coolberg Non Alcoholic Beer Assorted Flavors 330ml Glass Bottle - Pack of 12 (330ml x 12) Peach, Mint, Malt, Cranberry, Ginger & Strawberry',
#  'Octavius | Suprabhatam Tez Kadak Tea - 1Kg | Extra Strong Assam Tea | Black Tea | Kadak Chai Patti | Strong Chai | Tea Powder | Chai Patti 1 kg | Taza Tea 1 kg | Garden Fresh Tea | Tea 1 Kg',
#  'Fanta Orange 600 ml',
#  'PediaSure Chocolate Drink Powder 1 kg',
#  'PediaSure Vanilla Delight Drink Powder 400 g (Carton)',
#  'Stings Energy Drink 250 ml',
#  'Real Activ Mixed Fruit 100% Juice 1 L',
#  'BalajAgro Meri Chai CHARMINAR TEA 1kg',
#  'Patanjali Special Chyawanprash 1 kg',
#  'Ensure Vanilla Drink Powder 400 g',
#  'Complan Royal Chocolate Powdered Drink 500 g',
#  'Storia Badam Shake 180 ml',
#  'Continental Speciale Instant Coffee 200g Pouch | 100% Pure Coffee',
#  'Horlicks Classic Malt 500 g',
#  'Real Active Orange Juice 1 L',
#  'Horlicks Chocolate Delight 500 g',
#  'Coca Cola 250 ml',
#  'Storia Chocolate Shake 180 ml',
#  'Tropicana Slice Mango Drink 600 ml',
#  'B Natural Guava Juice 180 ml',
#  'Horlicks Classic Malt 1 kg',
#  'Continental XTRA Coffee Powder 200gm Pouch | Strongest Instant Coffee | PACK OF 2 | 400gm']

# %%
product_price
# Out:
# ['₹50.00',
#  '₹299.00',
#  '₹450.00',
#  '₹32.00',
#  '₹75.00',
#  '₹195.00',
#  '₹13.00',
#  '₹792.00',
#  '₹390.00',
#  '₹18.00',
#  '₹74.00',
#  '₹361.00',
#  '₹189.00',
#  '₹84.00',
#  '₹66.00',
#  '₹400.00',
#  '₹30.00',
#  '₹639.00',
#  '₹32.00',
#  '₹199.00',
#  '₹235.00',
#  '₹32.00',
#  '₹357.00',
#  '₹195.00',
#  '₹82.00',
#  '₹32.00',
#  '₹71.00',
#  '₹329.00',
#  '₹207.00',
#  '₹195.00',
#  '₹161.00',
#  '₹32.00',
#  '₹66.00',
#  '₹295.00',
#  '₹455.00',
#  '₹790.00',
#  '₹480.00',
#  '₹32.00',
#  '₹142.00',
#  '₹79.00',
#  '₹130.00',
#  '₹864.00',
#  '₹29.00',
#  '₹70.00',
#  '₹25.00',
#  '₹239.00',
#  '₹300.00',
#  '₹195.00',
#  '₹99.00',
#  '₹279.00',
#  '₹69.00',
#  '₹240.00',
#  '₹89.00',
#  '₹195.00',
#  '₹90.00',
#  '₹165.00',
#  '₹60.00',
#  '₹27.00',
#  '₹231.00',
#  '₹139.00',
#  '₹18.00',
#  '₹75.00',
#  '₹290.00',
#  '₹310.00',
#  '₹33.00',
#  '₹18.00',
#  '₹140.00',
#  '₹32.00',
#  '₹150.00',
#  '₹295.00',
#  '₹266.00',
#  '₹170.00',
#  '₹70.00',
#  '₹32.00',
#  '₹26.00',
#  '₹230.00',
#  '₹33.00',
#  '₹295.00',
#  '₹130.00',
#  '₹88.00',
#  '₹134.00',
#  '₹145.00',
#  '₹144.00',
#  '₹516.00',
#  '₹129.00',
#  '₹199.00',
#  '₹18.00',
#  '₹70.00',
#  '₹65.00',
#  '₹265.00',
#  '₹189.00',
#  '₹719.00',
#  '₹67.00',
#  '₹70.00',
#  '₹210.00',
#  '₹515.00',
#  '₹85.00',
#  '₹94.00',
#  '₹599.00',
#  '₹26.00',
#  '₹33.00',
#  '₹26.00',
#  '₹262.00',
#  '₹179.00',
#  '₹89.00',
#  '₹260.00',
#  '₹70.00',
#  '₹340.00',
#  '₹18.00',
#  '₹299.00',
#  '₹144.00',
#  '₹6.00',
#  '₹505.00',
#  '₹39.00',
#  '₹297.00',
#  '₹231.00',
#  '₹27.00',
#  '₹479.00',
#  '₹18.00',
#  '₹15.00',
#  '₹1,092.00',
#  '₹179.00',
#  '₹33.00',
#  '₹1,416.00',
#  '₹652.00',
#  '₹27.00',
#  '₹99.00',
#  '₹200.00',
#  '₹270.00',
#  '₹698.00',
#  '₹284.00',
#  '₹30.00',
#  '₹339.00',
#  '₹264.00',
#  '₹99.00',
#  '₹209.00',
#  '₹18.00',
#  '₹30.00',
#  '₹32.00',
#  '₹15.00',
#  '₹494.00',
#  '₹549.00']

# %%
product_discount
# Out:
# ['33% OFF',
#  '25% OFF',
#  '25% OFF',
#  '23% OFF',
#  '11% OFF',
#  '61% OFF',
#  '35% OFF',
#  '10% OFF',
#  '18% OFF',
#  '10% OFF',
#  '25% OFF',
#  '5% OFF',
#  '37% OFF',
#  '32% OFF',
#  '33% OFF',
#  '29% OFF',
#  '25% OFF',
#  '54% OFF',
#  '20% OFF',
#  '13% OFF',
#  '21% OFF',
#  '20% OFF',
#  '19% OFF',
#  '61% OFF',
#  '8% OFF',
#  '20% OFF',
#  '28% OFF',
#  '26% OFF',
#  '10% OFF',
#  '61% OFF',
#  '26% OFF',
#  '20% OFF',
#  '33% OFF',
#  '25% OFF',
#  '24% OFF',
#  '16% OFF',
#  '15% OFF',
#  '20% OFF',
#  '11% OFF',
#  '21% OFF',
#  '10% OFF',
#  '10% OFF',
#  '27% OFF',
#  '50% OFF',
#  '28% OFF',
#  '17% OFF',
#  '45% OFF',
#  '61% OFF',
#  '17% OFF',
#  '26% OFF',
#  '18% OFF',
#  '35% OFF',
#  '50% OFF',
#  '61% OFF',
#  '21% OFF',
#  '40% OFF',
#  '14% OFF',
#  '10% OFF',
#  '42% OFF',
#  '10% OFF',
#  '10% OFF',
#  '11% OFF',
#  '13% OFF',
#  '11% OFF',
#  '13% OFF',
#  '10% OFF',
#  '22% OFF',
#  '20% OFF',
#  '11% OFF',
#  '11% OFF',
#  '30% OFF',
#  'None',
#  '50% OFF',
#  '20% OFF',
#  '25% OFF',
#  'None',
#  '34% OFF',
#  '14% OFF',
#  '7% OFF',
#  '7% OFF',
#  '7% OFF',
#  '9% OFF',
#  '7% OFF',
#  '10% OFF',
#  '13% OFF',
#  '42% OFF',
#  '10% OFF',
#  '50% OFF',
#  '53% OFF',
#  '8% OFF',
#  '50% OFF',
#  '12% OFF',
#  '52% OFF',
#  '50% OFF',
#  '10% OFF',
#  '16% OFF',
#  '7% OFF',
#  '26% OFF',
#  '20% OFF',
#  '25% OFF',
#  '13% OFF',
#  '35% OFF',
#  '52% OFF',
#  '18% OFF',
#  '50% OFF',
#  '32% OFF',
#  '50% OFF',
#  '24% OFF',
#  '10% OFF',
#  '14% OFF',
#  '7% OFF',
#  'None',
#  '28% OFF',
#  '7% OFF',
#  '4% OFF',
#  '17% OFF',
#  '22% OFF',
#  '21% OFF',
#  '10% OFF',
#  '25% OFF',
#  '8% OFF',
#  '25% OFF',
#  '13% OFF',
#  '20% OFF',
#  '15% OFF',
#  '10% OFF',
#  '36% OFF',
#  '16% OFF',
#  '25% OFF',
#  '12% OFF',
#  '10% OFF',
#  '33% OFF',
#  '34% OFF',
#  '7% OFF',
#  '36% OFF',
#  '16% OFF',
#  '10% OFF',
#  '33% OFF',
#  '8% OFF',
#  '25% OFF',
#  '10% OFF',
#  '27% OFF']

# %%
data = {'Product Name':product_name,'Price':product_price,'Discount':product_discount}
df = pd.DataFrame(data)

# %%
df['Discount'] = df['Discount'].replace('None','0% OFF')

# %%
print(df['Price'].min())
# Out:
# ₹1,092.00

# %%
df_sorted = df.sort_values(by='Price',ascending=True)
df_sorted
# Out:
#                                           Product Name      Price Discount
# 120  Coolberg Non Alcoholic Beer Assorted Flavors 3...  ₹1,092.00   8% OFF
# 123              PediaSure Chocolate Drink Powder 1 kg  ₹1,416.00  20% OFF
# 84   ColombianBrewCoffee Arabica Espresso Filter Co...    ₹129.00  13% OFF
# 6                                  Bisleri Soda 750 ml     ₹13.00  35% OFF
# 78    Lipton Honey Lemon Green Tea Bags 1.4 g (25 pcs)    ₹130.00   7% OFF
# ..                                                 ...        ...      ...
# 54                    Real Fruit Power Apple Juice 1 L     ₹90.00  21% OFF
# 97              Real Fruit Power Mixed Fruit Juice 1 L     ₹94.00  26% OFF
# 126              Real Activ Mixed Fruit 100% Juice 1 L     ₹99.00  36% OFF
# 48                              Frooti Mango Drink 2 L     ₹99.00  17% OFF
# 134                       Real Active Orange Juice 1 L     ₹99.00  36% OFF
#
# [142 rows x 3 columns]

# %%
# Price C
df['Price'] = df['Price'].str[1:]

# %%
df['Price'] = df['Price'].str.replace(',', '').astype(float)

# %%
df['Discount'] = df['Discount'].str[0:-5]
df['Discount'] = df['Discount'].astype(float)

# %%
df
# Out:
#                                           Product Name  Price  Discount
# 0                              Maaza Mango Drink 1.2 L   50.0      33.0
# 1    Biovitalia Organics Watermelon Flavored Nutrac...  299.0      25.0
# 2          Brooke Bond Red Label Strong Blend Tea 1 kg  450.0      25.0
# 3                             Maaza Mango Drink 600 ml   32.0      23.0
# 4                                      Thums Up 2.25 L   75.0      11.0
# ..                                                 ...    ...       ...
# 137                      Storia Chocolate Shake 180 ml   30.0      33.0
# 138                 Tropicana Slice Mango Drink 600 ml   32.0       8.0
# 139                       B Natural Guava Juice 180 ml   15.0      25.0
# 140                         Horlicks Classic Malt 1 kg  494.0      10.0
# 141  Continental XTRA Coffee Powder 200gm Pouch | S...  549.0      27.0
#
# [142 rows x 3 columns]

# %%
df['Original Price'] = df['Price'] / (1 - df['Discount']/100)
df['Original Price'] = round(df['Original Price'])

# %%
df
# Out:
#                                           Product Name  Price  Discount  \
# 0                              Maaza Mango Drink 1.2 L   50.0      33.0
# 1    Biovitalia Organics Watermelon Flavored Nutrac...  299.0      25.0
# 2          Brooke Bond Red Label Strong Blend Tea 1 kg  450.0      25.0
# 3                             Maaza Mango Drink 600 ml   32.0      23.0
# 4                                      Thums Up 2.25 L   75.0      11.0
# ..                                                 ...    ...       ...
# 137                      Storia Chocolate Shake 180 ml   30.0      33.0
# 138                 Tropicana Slice Mango Drink 600 ml   32.0       8.0
# 139                       B Natural Guava Juice 180 ml   15.0      25.0
# 140                         Horlicks Classic Malt 1 kg  494.0      10.0
# 141  Continental XTRA Coffee Powder 200gm Pouch | S...  549.0      27.0
#
#      Original Price
# 0              75.0
# 1             399.0
# 2             600.0
# 3              42.0
# 4              84.0
# ..              ...
# 137            45.0
# 138            35.0
# 139            20.0
# 140           549.0
# 141           752.0
#
# [142 rows x 4 columns]

# %%
df.to_csv('JioMart.csv',index=False)
