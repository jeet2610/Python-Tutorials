# %%
import pandas as pd

df = pd.read_csv('dataset/salary_data.csv')

# %%
# salary with avg value
avg_value = df['Salary'].mean()
df['Salary'].fillna(avg_value,inplace=True)
# experience with avg value
avg_experience = df['Years of Experience'].mean()
df['Years of Experience'].fillna(avg_experience,inplace=True)

# %%
salary = df['Salary']
years= df['Years of Experience']

# %%
df_sliced = df[['Salary','Years of Experience']]

# %%
df_sliced.to_csv('dataset/SalaryvsExperience.csv',index=False)

# %%
# Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dataset = pd.read_csv('dataset/SalaryvsExperience.csv')
dataset.head()
# Out:
#      Salary  Years of Experience
# 0   90000.0                  5.0
# 1   65000.0                  3.0
# 2  150000.0                 15.0
# 3   60000.0                  7.0
# 4  200000.0                 20.0

# %%
# Locating the 
X = dataset.loc[:,"Years of Experience":].values
y = dataset.loc[:,"Salary"].values

# %%
# X = np.array(dataset['Years of Experience'])
# y = np.array(dataset['Salary'])
# X = X.reshape(2,-1)
# y = y.reshape(2,-1)
# print(X)
# print(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test = train_test_split(X,y,test_size=1/3,random_state=0)

# %%
X_train
# Out:
# array([[14.],
#        [ 2.],
#        [ 9.],
#        ...,
#        [12.],
#        [30.],
#        [11.]])

# %%
y_train
# Out:
# array([185000.,  40000., 195000., ..., 170000., 183020., 160000.])

# %%
# fitting the regression model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# predicting the test set results 
y_pred = regressor.predict(X)

# %%
plt.scatter(X_train,y_train,color='red')
plt.plot(X_train,regressor.predict(X_train),color="blue")
plt.title("Training Set")
plt.show()

# %%
plt.scatter(X_test,y_test,color='red')
plt.plot(X_train,regressor.predict(X_train),color='blue')
plt.title("Testing Set")
plt.show()
