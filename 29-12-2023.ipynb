# %% [markdown]
# # Seaborn

# %%
#import libraries
import seaborn as sns

#applying the default theme
sns.set_theme()

#load an example dataset
tips = sns.load_dataset("tips")

#create a visualization
sns.relplot(
    data=tips,
    x="total_bill",y="tip",col="time",
    hue="smoker",style="smoker",size="size")

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def sinplot(n=10,flip=1):
    x = np.linspace(0,14,100)
    for i in range(1,n+1):
        plt.plot(x,np.sin(x+i*.5)*(n+2-i)*flip)
sns.set_theme(style='darkgrid',palette='deep')
sinplot()

# %%
# Plotting Barplot using Seaborn
import seaborn as sns

sns.barplot(x=["A","B","C"],y=[1,2,3])
sns.set_theme(style="darkgrid",palette="deep")

# %%
sns.set_theme(style="whitegrid", palette="pastel")
sns.barplot(x=["A", "B", "C"], y=[1, 3, 2])

# %%
custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", rc=custom_params)
sns.barplot(x=["A", "B", "C"], y=[1, 3, 2])

# %%
# Exercises on Seaborn

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sales = pd.read_excel('D:\\Data analysis\\sales.xlsx')
sales.head()

# %%
sns.relplot(
    data=sales,
    x="Sales",
    y="Profit"
           )

# %%
sns.relplot(
    data=sales,
    x="Sales",
    y="Profit",
    hue="Order Priority"
           )

# %%
sns.relplot(
    data=sales,
    x="Sales",
    y="Profit",
    hue="Order Priority",
    style="Order Priority"
           )

# %%
sns.relplot(
    data=sales,
    x="Sales",
    y="Profit",
    hue="Order Priority",
    style="Ship Mode"
           )

# %%
sns.relplot(
    data=sales,
    x="Sales",
    y="Profit",
    size='Discount',
    sizes=(25,200),
    hue="Discount"
           )

# %%
sns.relplot(
    data=sales,
    x= 'Order Date',
    y= 'Sales',
    kind='line'
    )
# Out:
# C:\Users\jeets\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sales['year'] = sales['Order Date'].dt.year

# %%
sales.year.unique()
# Out:
# array([2010, 2012, 2011, 2009])

# %%
sns.relplot(data=sales,x='year',y='Sales',kind='line',linestyle=":")
# Out:
# C:\Users\jeets\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data=sales,x='year',y='Sales',kind='line',errorbar=None)
# Out:
# C:\Users\jeets\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data=sales,x='year',y='Sales',kind='line',errorbar='sd')
# Out:
# C:\Users\jeets\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data = sales,x='year',y='Sales',kind='line',estimator=None)
# Out:
# C:\Users\jeets\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data = sales,x='year',y='Sales',kind='line',estimator=sum)
# Out:
# C:\Users\jeets\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data = sales,x='year',y='Sales',kind='line',hue="Ship Mode",errorbar=None)
# Out:
# C:\Users\jeets\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data = sales,x='year',y='Sales',kind='line',hue="Ship Mode",errorbar=None,style='Product Category')
# Out:
# C:\Users\jeets\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data = sales,x='year',y='Sales',kind='line',hue="Ship Mode",errorbar=None,col='Product Category',style='Product Category')
# Out:
# C:\Users\jeets\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data = sales,x='year',y='Sales',kind='line',hue="Ship Mode",errorbar=None,col='Region',style='Product Category')
# Out:
# C:\Users\jeets\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data = sales,x='year',y='Sales',kind='line',hue="Ship Mode",errorbar=None,col='Region',style='Product Category',col_wrap=4)
# Out:
# C:\Users\jeets\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data = sales,x='year',y='Sales',kind='line',hue="Ship Mode",errorbar=None,col='Region',style='Product Category',col_wrap=2)
# Out:
# C:\Users\jeets\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
